# %%
import os
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
path = '..'
os.chdir(path)

# %%
baseURL = 'apis.data.go.kr/1160100/service'
getApis = {
   # 'GetSBProfileInfoService' : ['getOtlInfo', 'getCsdoStatus'], # 개인사업자 기본정보
   # 'GetSBBankingInfoService' : ['getGrnBalInfo', 'getDpstLoanInfo'], # 개인사업자
   # 'GetSBFinanceInfoService' : ['getFnafInfo', 'getSlsInfo', 'getDbtInfo'], # 개인사업자
   'GetCorpBasicInfoService_V2' :  # 기업 기본정보
      [ 
         'getAffiliate_V2',
         'getConsSubsComp_V2',
         'getCorpOutline_V2'
      ],
   'GetFinaStatInfoService_V2' : # 기업 재무정보
      [
         'getIncoStat_V2',
         'getBs_V2',
         'getSummFinaStat_V2'
      ],
}

# %%
# baseURL = 'apis.data.go.kr/1160100/service/GetSBProfileInfoService' /
# apis.data.go.kr/1160100/service/GetCorpBasicInfoService_V2

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Pro\\Documents\\workspace\\analysis_soleProprietor'

# %%
def getApiData(apis: dict | list, baseURL: str = baseURL, start: int = 0, rows: int = 10000, scope: int = 100, current_path: str = os.getcwd()):
    
    scope = start + scope

    key = os.getenv('KEY_DECODE')
    if not key:
        logging.error("API key not found in environment variables.")
        return

    # apis 형태 처리
    if isinstance(apis, dict):
        base = list(apis.keys())
        api = list(apis.values())
    else:
        base = [baseURL.split('/')[-1]]
        api = apis
        baseURL = baseURL.replace(f'/{base[0]}', '')

    # 세션 및 재시도 설정
    session = requests.Session()
    retries = Retry(total=3, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
    session.mount('http://', HTTPAdapter(max_retries=retries))

    for base_item, api_list in zip(base, api):
        for api_item in api_list:
            logging.info(f"[START] Collecting: http://{baseURL}/{base_item}/{api_item}")
            for page in range(start, scope):
                url = f"http://{baseURL}/{base_item}/{api_item}"
                params = {
                    "serviceKey": key,
                    "pageNo": page + 1,
                    "numOfRows": rows,
                    "resultType": "json"
                }

                try:
                    response = session.get(url, params=params)
                    response.raise_for_status()
                except requests.exceptions.RequestException as e:
                    logging.error(f"Request failed for {url} (page {page+1}): {e}")
                    break

                logging.info(f"Collecting page {page + 1}...")

                try:
                    response_data = response.json().get('response', {}).get('body', {}).get('items', {}).get('item', [])
                except ValueError as e:
                    logging.error(f"Invalid JSON response from {url}: {e}")
                    break
                
                is_last_page = len(response_data) < rows

                if response_data:
                    try:
                        df = pd.DataFrame(response_data)
                    except ValueError as e:
                        logging.error(f"Error converting response to DataFrame on page {page + 1}: {e}")
                        break

                    save_path = os.path.join(current_path, 'dataset', base_item, api_item)
                    try:
                        os.makedirs(save_path, exist_ok=True)
                    except OSError as e:
                        logging.error(f"Failed to create directory {save_path}: {e}")
                        break

                    file_name = os.path.join(save_path, f"{api_item}_{str(page).zfill(3)}.csv")
                    try:
                        df.to_csv(file_name, index=False)
                        logging.info(f"Saved: {file_name}")
                    except PermissionError as e:
                        logging.error(f"Permission denied when saving file {file_name}: {e}")
                        break
                else:
                    logging.info(f"Page {page + 1} returned no data.")

                # 데이터가 지정 rows 미만이면 마지막 페이지로 간주하고 중단
                if is_last_page:
                    logging.info(f"end of pages: less then {rows} rows.")
                    break

# %%
getApiData(getApis)
# Out:
# INFO:root:[START] Collecting: http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService_V2/getAffiliate_V2
# INFO:root:Collecting page 101...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_100.csv
# INFO:root:Collecting page 102...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_101.csv
# INFO:root:Collecting page 103...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_102.csv
# INFO:root:Collecting page 104...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_103.csv
# INFO:root:Collecting page 105...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_104.csv
# INFO:root:Collecting page 106...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_105.csv
# INFO:root:Collecting page 107...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_106.csv
# INFO:root:Collecting page 108...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_107.csv
# INFO:root:Collecting page 109...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_108.csv
# INFO:root:Collecting page 110...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_109.csv
# INFO:root:Collecting page 111...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_110.csv
# INFO:root:Collecting page 112...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_111.csv
# INFO:root:Collecting page 113...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_112.csv
# INFO:root:Collecting page 114...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_113.csv
# INFO:root:Collecting page 115...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_114.csv
# INFO:root:Collecting page 116...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_115.csv
# INFO:root:Collecting page 117...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_116.csv
# INFO:root:Collecting page 118...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_117.csv
# INFO:root:Collecting page 119...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_118.csv
# INFO:root:Collecting page 120...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_119.csv
# INFO:root:Collecting page 121...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_120.csv
# INFO:root:Collecting page 122...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_121.csv
# INFO:root:Collecting page 123...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_122.csv
# INFO:root:Collecting page 124...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_123.csv
# INFO:root:Collecting page 125...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_124.csv
# INFO:root:Collecting page 126...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_125.csv
# INFO:root:Collecting page 127...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_126.csv
# INFO:root:Collecting page 128...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_127.csv
# INFO:root:Collecting page 129...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_128.csv
# INFO:root:Collecting page 130...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_129.csv
# INFO:root:Collecting page 131...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_130.csv
# INFO:root:Collecting page 132...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_131.csv
# INFO:root:Collecting page 133...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_132.csv
# INFO:root:Collecting page 134...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_133.csv
# INFO:root:Collecting page 135...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_134.csv
# INFO:root:Collecting page 136...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_135.csv
# INFO:root:Collecting page 137...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_136.csv
# INFO:root:Collecting page 138...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_137.csv
# INFO:root:Collecting page 139...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_138.csv
# INFO:root:Collecting page 140...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_139.csv
# INFO:root:Collecting page 141...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_140.csv
# INFO:root:Collecting page 142...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_141.csv
# INFO:root:Collecting page 143...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_142.csv
# INFO:root:Collecting page 144...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_143.csv
# INFO:root:Collecting page 145...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_144.csv
# INFO:root:Collecting page 146...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_145.csv
# INFO:root:Collecting page 147...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_146.csv
# INFO:root:Collecting page 148...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_147.csv
# INFO:root:Collecting page 149...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_148.csv
# INFO:root:Collecting page 150...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_149.csv
# INFO:root:Collecting page 151...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_150.csv
# INFO:root:Collecting page 152...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_151.csv
# INFO:root:Collecting page 153...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_152.csv
# INFO:root:Collecting page 154...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_153.csv
# INFO:root:Collecting page 155...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_154.csv
# INFO:root:Collecting page 156...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_155.csv
# INFO:root:Collecting page 157...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_156.csv
# INFO:root:Collecting page 158...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_157.csv
# INFO:root:Collecting page 159...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_158.csv
# INFO:root:Collecting page 160...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_159.csv
# INFO:root:Collecting page 161...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_160.csv
# INFO:root:Collecting page 162...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_161.csv
# INFO:root:Collecting page 163...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_162.csv
# INFO:root:Collecting page 164...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_163.csv
# INFO:root:Collecting page 165...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_164.csv
# INFO:root:Collecting page 166...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_165.csv
# INFO:root:Collecting page 167...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_166.csv
# INFO:root:Collecting page 168...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_167.csv
# INFO:root:Collecting page 169...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_168.csv
# INFO:root:Collecting page 170...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_169.csv
# INFO:root:Collecting page 171...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_170.csv
# INFO:root:Collecting page 172...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_171.csv
# INFO:root:Collecting page 173...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_172.csv
# INFO:root:Collecting page 174...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_173.csv
# INFO:root:Collecting page 175...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_174.csv
# INFO:root:Collecting page 176...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_175.csv
# INFO:root:Collecting page 177...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_176.csv
# INFO:root:Collecting page 178...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_177.csv
# INFO:root:Collecting page 179...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_178.csv
# INFO:root:Collecting page 180...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_179.csv
# INFO:root:Collecting page 181...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_180.csv
# INFO:root:Collecting page 182...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_181.csv
# INFO:root:Collecting page 183...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_182.csv
# INFO:root:Collecting page 184...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_183.csv
# INFO:root:Collecting page 185...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_184.csv
# INFO:root:Collecting page 186...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_185.csv
# INFO:root:Collecting page 187...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_186.csv
# INFO:root:Collecting page 188...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_187.csv
# INFO:root:Collecting page 189...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_188.csv
# INFO:root:Collecting page 190...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_189.csv
# INFO:root:Collecting page 191...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_190.csv
# INFO:root:Collecting page 192...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_191.csv
# INFO:root:Collecting page 193...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_192.csv
# INFO:root:Collecting page 194...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_193.csv
# INFO:root:Collecting page 195...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_194.csv
# INFO:root:Collecting page 196...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_195.csv
# INFO:root:Collecting page 197...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_196.csv
# INFO:root:Collecting page 198...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_197.csv
# INFO:root:Collecting page 199...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_198.csv
# INFO:root:Collecting page 200...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetCorpBasicInfoService_V2\getAffiliate_V2\getAffiliate_V2_199.csv
# INFO:root:[START] Collecting: http://apis.data.go.kr/1160100/service/GetFinaStatInfoService_V2/getSummFinaStat_V2
# INFO:root:Collecting page 101...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_100.csv
# INFO:root:Collecting page 102...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_101.csv
# INFO:root:Collecting page 103...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_102.csv
# INFO:root:Collecting page 104...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_103.csv
# INFO:root:Collecting page 105...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_104.csv
# INFO:root:Collecting page 106...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_105.csv
# INFO:root:Collecting page 107...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_106.csv
# INFO:root:Collecting page 108...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_107.csv
# INFO:root:Collecting page 109...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_108.csv
# INFO:root:Collecting page 110...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_109.csv
# INFO:root:Collecting page 111...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_110.csv
# INFO:root:Collecting page 112...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_111.csv
# INFO:root:Collecting page 113...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_112.csv
# INFO:root:Collecting page 114...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_113.csv
# INFO:root:Collecting page 115...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_114.csv
# INFO:root:Collecting page 116...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_115.csv
# INFO:root:Collecting page 117...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_116.csv
# INFO:root:Collecting page 118...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_117.csv
# INFO:root:Collecting page 119...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_118.csv
# INFO:root:Collecting page 120...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_119.csv
# INFO:root:Collecting page 121...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_120.csv
# INFO:root:Collecting page 122...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_121.csv
# INFO:root:Collecting page 123...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_122.csv
# INFO:root:Collecting page 124...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_123.csv
# INFO:root:Collecting page 125...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_124.csv
# INFO:root:Collecting page 126...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_125.csv
# INFO:root:Collecting page 127...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_126.csv
# INFO:root:Collecting page 128...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_127.csv
# INFO:root:Collecting page 129...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_128.csv
# INFO:root:Collecting page 130...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_129.csv
# INFO:root:Collecting page 131...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_130.csv
# INFO:root:Collecting page 132...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_131.csv
# INFO:root:Collecting page 133...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_132.csv
# INFO:root:Collecting page 134...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_133.csv
# INFO:root:Collecting page 135...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_134.csv
# INFO:root:Collecting page 136...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_135.csv
# INFO:root:Collecting page 137...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_136.csv
# INFO:root:Collecting page 138...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_137.csv
# INFO:root:Collecting page 139...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_138.csv
# INFO:root:Collecting page 140...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_139.csv
# INFO:root:Collecting page 141...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_140.csv
# INFO:root:Collecting page 142...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_141.csv
# INFO:root:Collecting page 143...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_142.csv
# INFO:root:Collecting page 144...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_143.csv
# INFO:root:Collecting page 145...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_144.csv
# INFO:root:Collecting page 146...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_145.csv
# INFO:root:Collecting page 147...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_146.csv
# INFO:root:Collecting page 148...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_147.csv
# INFO:root:Collecting page 149...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_148.csv
# INFO:root:Collecting page 150...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_149.csv
# INFO:root:Collecting page 151...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_150.csv
# INFO:root:Collecting page 152...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_151.csv
# INFO:root:Collecting page 153...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_152.csv
# INFO:root:Collecting page 154...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_153.csv
# INFO:root:Collecting page 155...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_154.csv
# INFO:root:Collecting page 156...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_155.csv
# INFO:root:Collecting page 157...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_156.csv
# INFO:root:Collecting page 158...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_157.csv
# INFO:root:Collecting page 159...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_158.csv
# INFO:root:Collecting page 160...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_159.csv
# INFO:root:Collecting page 161...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_160.csv
# INFO:root:Collecting page 162...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_161.csv
# INFO:root:Collecting page 163...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_162.csv
# INFO:root:Collecting page 164...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_163.csv
# INFO:root:Collecting page 165...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_164.csv
# INFO:root:Collecting page 166...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_165.csv
# INFO:root:Collecting page 167...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_166.csv
# INFO:root:Collecting page 168...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_167.csv
# INFO:root:Collecting page 169...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_168.csv
# INFO:root:Collecting page 170...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_169.csv
# INFO:root:Collecting page 171...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_170.csv
# INFO:root:Collecting page 172...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_171.csv
# INFO:root:Collecting page 173...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_172.csv
# INFO:root:Collecting page 174...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_173.csv
# INFO:root:Collecting page 175...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_174.csv
# INFO:root:Collecting page 176...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_175.csv
# INFO:root:Collecting page 177...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_176.csv
# INFO:root:Collecting page 178...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_177.csv
# INFO:root:Collecting page 179...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_178.csv
# INFO:root:Collecting page 180...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_179.csv
# INFO:root:Collecting page 181...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_180.csv
# INFO:root:Collecting page 182...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_181.csv
# INFO:root:Collecting page 183...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_182.csv
# INFO:root:Collecting page 184...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_183.csv
# INFO:root:Collecting page 185...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_184.csv
# INFO:root:Collecting page 186...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_185.csv
# INFO:root:Collecting page 187...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_186.csv
# INFO:root:Collecting page 188...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_187.csv
# INFO:root:Collecting page 189...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_188.csv
# INFO:root:Collecting page 190...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_189.csv
# INFO:root:Collecting page 191...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_190.csv
# INFO:root:Collecting page 192...
# INFO:root:Saved: c:\Users\Pro\Documents\workspace\analysis_soleProprietor\dataset\GetFinaStatInfoService_V2\getSummFinaStat_V2\getSummFinaStat_V2_191.csv
# INFO:root:end of pages: less then 10000 rows.

# %%
def process_csv_files(getApis, current_path: str = os.getcwd()):
    # Process each path to handle CSV files
    for key, values in getApis.items():
        if not values:  # If no values, skip
            logging.warning(f"The value for '{key}' is empty.")
            continue

        for value in values:
            full_path = f'{current_path}/dataset/{key}/{value}'

            # Retrieve list of CSV files in the directory
            try:
                if not os.path.exists(full_path):
                    logging.warning(f"Directory {full_path} does not exist. Skipping this path.")
                    continue  # Skip if the directory does not exist

                file_list = sorted([f for f in os.listdir(full_path) if f.endswith('.csv')])
                if not file_list:
                    logging.warning(f"There are no CSV files in {full_path}.")
                    continue  # Skip if no CSV files exist in the directory
            except Exception as e:
                logging.error(f"An error occurred with the directory {full_path}: {e}")
                continue  # Skip if there's an error with the directory

            # List to hold DataFrames
            all_data = []
            # Iterate over each file and read the data
            for filename in file_list:
                try:
                    file_path = os.path.join(full_path, filename)
                    tmp = pd.read_csv(file_path)
                    if tmp.empty:  # Handle empty files
                        logging.warning(f"The file {filename} is empty. Skipping this file.")
                        continue  # Skip empty files
                    all_data.append(tmp)  # Add file to the list
                except Exception as e:
                    logging.error(f"An error occurred while reading the file {filename}: {e}")

            # Combine all DataFrames into one
            if all_data:
                try:
                    df = pd.concat(all_data, ignore_index=True)
                    output_path = os.path.join(full_path, "all.csv")
                    df.to_csv(output_path, index=False)
                    logging.info(f"Successfully combined all data into 'all.csv' in {full_path}.")
                except Exception as e:
                    logging.error(f"An error occurred while merging all data: {e}")
            else:
                logging.warning(f"There are no valid CSV files in {full_path}.")

# %%
process_csv_files(getApis)
# Out:
# INFO:root:c:\Users\Pro\Documents\workspace\analysis_soleProprietor/dataset/GetCorpBasicInfoService_V2/getConsSubsComp_V2에 모든 데이터를 합쳐서 'all.csv'로 저장 완료.
# INFO:root:c:\Users\Pro\Documents\workspace\analysis_soleProprietor/dataset/GetCorpBasicInfoService_V2/getCorpOutline_V2에 모든 데이터를 합쳐서 'all.csv'로 저장 완료.
# INFO:root:c:\Users\Pro\Documents\workspace\analysis_soleProprietor/dataset/GetFinaStatInfoService_V2/getIncoStat_V2에 모든 데이터를 합쳐서 'all.csv'로 저장 완료.
# INFO:root:c:\Users\Pro\Documents\workspace\analysis_soleProprietor/dataset/GetFinaStatInfoService_V2/getBs_V2에 모든 데이터를 합쳐서 'all.csv'로 저장 완료.
